# %% [markdown]
# <a href="https://colab.research.google.com/github/no22089/CE880-Lab-Task/blob/main/week_2_exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/sagihaider/CE880.git
# Out:
# Cloning into 'CE880'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 403 (delta 120), reused 197 (delta 106), pack-reused 183
# Receiving objects: 100% (403/403), 7.81 MiB | 22.28 MiB/s, done.
# Resolving deltas: 100% (187/187), done.

# %%
# Unzip Data 
from zipfile import ZipFile
file_name = "/content/CE880/Data/Data.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import pandas as pd
filename ="/content/Data/heart.csv"
data = pd.read_csv(filename)
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
import pandas as pd
filename ="/content/Data/HR.xlsx"
data1 = pd.read_excel(filename)
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
with open(r'/content/Data/Shakespeare.txt', 'r') as f:
  print(f.read())
# Out:
# If you cannot understand my argument,
# and declare "It's Greek to me",
# you are quoting Shakespeare;
# if you claim to be more sinned against than sinning,
# you are quoting Shakespeare;
# if you recall your salad days,
# you are quoting Shakespeare;
# if you act more in sorrow than in anger,
# if your wish is father to the thought,
# if your lost property has vanished into thin air,
# you are quoting Shakespeare;
# if you have ever refused to budge an inch or suffered from green-eyed jealousy,
# if you have played fast and loose,
# if you have been tongue-tied,
# a tower of strength,
# hoodwinked or in a pickle,
# if you have knitted your brows,
# made a virtue of necessity,
# insisted on fair play,
# slept not one wink,
# stood on ceremony,
# danced attendance (on your lord and master),
# laughed yourself into stitches,
# had short shrift,
# cold comfort or too much of a good thing,
# if you have seen better days or lived in a fool's paradise - why,
# be that as it may,
# ...

# %%
import json
filename ="/content/Data/TB.json"
with open(filename, 'r') as json_file:
     json_data = json.load(json_file)

data3 = pd.DataFrame(json_data)
data3
# Out:
#        no          id       name  gender        date      time  \
# 0       1  7810789740      Gerik    Male   1/25/2021  10:51 AM
# 1       2  3263348302     Rafael  Female  10/15/2020   5:18 PM
# 2       3  6746607208     Meriel    Male   5/16/2020   9:19 AM
# 3       4  7334455746         Hy    Male   12/1/2020  11:23 AM
# 4       5  8364135376     Abramo    Male    8/4/2020  11:51 AM
# ..    ...         ...        ...     ...         ...       ...
# 995   996  0270574999  Simonette  Female    8/1/2020   2:40 PM
# 996   997  7241513312      Edmon  Female   2/16/2020   2:18 PM
# 997   998  1331588782   Gardener    Male    7/5/2020   3:38 PM
# 998   999  0079243134       Arel    Male  12/14/2020  11:31 AM
# 999  1000  2442974630  Dominique    Male  11/19/2020   6:47 PM
#
#      fever for two weeks  coughing blood  sputum mixed with blood  \
# 0                      0               0                        0
# 1                      0               0                        0
# ...
